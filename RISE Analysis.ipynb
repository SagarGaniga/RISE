# %%
import numpy as np
import numpy.random as random
import pandas as pd
import pylab 
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("Data/Rise Attributes Moments Posted Report.xls")
df = df.iloc[5:]
df = df.drop(['End Date'], axis=1)
df = df.rename(index=str, columns={"Report input": "MP", "Start Date":"Attribute"})
df = df.reset_index()
df = df.drop(['index'], axis=1)

# %%
header = ['MP', 'Attribute']
df.to_csv("MP-Attribute.csv", columns=header)

# %%
df_mp = pd.read_csv("MP-Attribute.csv")
df = df_mp.drop(df_mp.columns[0], axis=1)

df.plot.bar()
plt.xlabel("Attribute")
plt.ylabel("MP")
plt.show()

# %%
x= df["MP"]
# print(x)

y = df["Attribute"]

plt.plot(x)
plt.show()
